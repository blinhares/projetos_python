# %% [markdown]
# # Aprendendo Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Declarando DataFrame e Series e mostrando estatisticas basicas.

# %%
df = pd.DataFrame({'B':[1,2,3,4,5,6]})
print(f'Imprime as infommacoes descritivas do dado: {df.describe()}')
# Out:
# Imprime as infommacoes descritivas do dado:               B
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %%
s = pd.Series([1,2,3,4,5])
print(s.describe())
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %% [markdown]
# Imprimindo as matematicas basicas de cada coluna:
# Para isso se utiliza o metodo 'describe()'

# %%
print(f'Descrevendo as estatisticas descritivas dos dados:\n {s.describe()}')
# Out:
# Descrevendo as estatisticas descritivas dos dados:
#  count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %% [markdown]
# Visualiza o desvio padrão das respectivas colunas:

# %%
print(f'Desvio padrão dos dados Vendas_Cafe: {s.std()}')
# Out:
# Desvio padrão dos dados Vendas_Cafe: 1.5811388300841898

# %% [markdown]
# # Fazendo Graficos (Plot)

# %% [markdown]
# Cria o gráfico de um histograma dos dados.
# Para isso, primeiro deve-se importar a biblioteca padrão para os gráficos.
#
# A Documentação do pandas solicita para fazer as importações abaixo. Mas nos testes não se fez nescessário.

# %%
import matplotlib.pyplot as plt 
plt.close('all') #limpa todas as figuras desenhadas

# %% [markdown]
# Criando um dado de serie...

# %%
dados= pd.DataFrame( 
    {'Vendas_Cafe' : [18, 20, 23, 23, 23, 23, 24, 25, 26, 26, 26, 26, 27, 28, 28,
29, 29, 30, 30, 31, 31, 33, 34, 35, 38, 39, 41, 44, 44, 46],
'Preco_Cafe' : [4.77, 4.67, 4.75, 4.74, 4.63, 4.56, 4.59, 4.75, 4.75, 4.49,
4.41, 4.32, 4.68, 4.66, 4.42, 4.71, 4.66, 4.46, 4.36, 4.47, 4.43,
4.4, 4.61, 4.09, 3.73, 3.89, 4.35, 3.84, 3.81, 3.79],
'Promocao' : ["Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Sim",
"Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Nao", "Sim", "Sim",
"Sim", "Nao", "Nao", "Sim", "Sim", "Sim", "Nao", "Sim", "Sim","Sim", "Sim", "Sim"],
'Preco_Leite' : [4.74, 4.81, 4.36, 4.29, 4.17, 4.66, 4.73, 4.11, 4.21, 4.25,
4.62, 4.53, 4.44, 4.19, 4.37, 4.29, 4.57, 4.21, 4.77, 4, 4.31,
4.34, 4.05, 4.73, 4.07, 4.75, 4, 4.15, 4.34, 4.15]
})

# %% [markdown]
# Para plotar a serie de dados basta colocar o nome do objeto.plot() como a seguir.

# %%
dados.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30212\2802851188.py in ?()
#       1 dados.hist()
# ----> 2 dados.show()
#       3
#       4
#
# c:\Users\b_lin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %% [markdown]
# Fazendo o Histograma de um unico dado e mudando o titulo central bem como os titulos dos eixos x e y.

# %% [markdown]
# Opção 01:

# %%
dados['Preco_Cafe'].plot(title='Preço do Café',kind='hist',xlabel='Preço em R$', ylabel='Dias')
# Out:
# <Axes: title={'center': 'Preço do Café'}, xlabel='Preço em R$', ylabel='Dias'>

# %% [markdown]
# Opção 02:
# Nesta segunda há uma maior flexibilidade de argumentos.

# %%
dados['Preco_Cafe'].plot.hist(title='Preço do Café',xlabel='Preço em R$', ylabel='Dias')
# Out:
# <Axes: title={'center': 'Preço do Café'}, xlabel='Preço em R$', ylabel='Dias'>

# %% [markdown]
# Para visualizar os 3 codigos na mesma pagina, fazemos:

# %%
dados.plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# é possivel somar graficos? Pesquisar...

# %% [markdown]
# Plotar o Gráfico de Preço Cafe VS Vendas Café:

# %%
dados.plot.scatter(x='Preco_Cafe', y='Vendas_Cafe', title='Preço do Cafe vs Vendas',ylabel='Vendas do Café', xlabel='Preço do Café (R$)' ,grid=True)
# Out:
# <Axes: title={'center': 'Preço do Cafe vs Vendas'}, xlabel='Preço do Café (R$)', ylabel='Vendas do Café'>

# %% [markdown]
# Para printar os pontos dos dias em promoção, sera nescessário criar uma coluna auxiliar no DataFrame que indique as cores.
#
# 1-Vamos criar uma função que receba um texto e baseado nelo retorne um valor em texto para a cor.
#
# Definiremos que :
#
# Se há Promoção : 'green'
#
#
# Se NÃO há Promoção : 'green'

# %%
def cor_da_promo(valor:str):
    if valor == "Nao":
        return 'blue'
    else:
        return 'green'

# %% [markdown]
# Com a função criada, vamos criar uma nova coluna do DataFrame chamada 'Cor_da_Promocao' que ira receber o retorno da função para cada item da coluna 'Promocao' do DataFrame correspondente.

# %%
dados['Cor_da_Promocao'] = dados['Promocao'].apply(cor_da_promo)

# %% [markdown]
# Imprimindo o novo data Frame, temos:

# %%
print(dados)
# Out:
#     Vendas_Cafe  Preco_Cafe Promocao  Preco_Leite Cor_da_Promocao
# 0            18        4.77      Nao         4.74            blue
# 1            20        4.67      Nao         4.81            blue
# 2            23        4.75      Nao         4.36            blue
# 3            23        4.74      Nao         4.29            blue
# 4            23        4.63      Nao         4.17            blue
# 5            23        4.56      Nao         4.66            blue
# 6            24        4.59      Nao         4.73            blue
# 7            25        4.75      Nao         4.11            blue
# 8            26        4.75      Sim         4.21           green
# 9            26        4.49      Nao         4.25            blue
# 10           26        4.41      Sim         4.62           green
# 11           26        4.32      Nao         4.53            blue
# 12           27        4.68      Nao         4.44            blue
# ...

# %% [markdown]
# Re-Plotar o Gráfico de Preço Cafe VS Vendas Café, agora considerando as cores.
#
# Para isso deve-se incluir o argumento 'c=' que recebe uma coluna com o nome das cores de acordo com cada índice.

# %%
dados.plot.scatter(x='Preco_Cafe', y='Vendas_Cafe', title='Preço do Cafe vs Vendas', ylabel='Vendas do Café', xlabel='Preço do Café (R$)', c=dados['Cor_da_Promocao'] ,grid=True)
# Out:
# <Axes: title={'center': 'Preço do Cafe vs Vendas'}, xlabel='Preço do Café (R$)', ylabel='Vendas do Café'>

# %% [markdown]
# Para usar o Plotly para desenhar os graficos há que fazer desta forma:
#
# import pandas as pd
# pd.options.plotting.backend = "plotly"
#
# df = pd.DataFrame(dict(a=[1,3,2], b=[3,2,1]))
# fig = df.plot()
# fig.show()

# %% [markdown]
# # opicional
# pega os nomes das colunas:
# lista_das_colunas=(list(dados.columns))
# print(dados.dtypes)

# %% [markdown]
# Sempre que nescessário se pode salvar o grafico plotado com o comando:
# plt.savefig('output.png')
